# %% [markdown]
# # Set working directory

# %%
import os
import pandas as pd
import random
import numpy as np
os.chdir("C:/Users/pz413sz/Documents/test_workflows")

# %%
from workflow import c_0_0_create_dataset

# %%
c_0_0_create_dataset.describe()
# Out:
# This module contains practice data available to us
# Seaborn data: anscombe, attention, brain_networks, car_crashes, diamonds, dots
# Seaborn data: exercise, flights, fmri, gammas, iris, mpg, planets, tips, titanic
# scikitlearn available datasets are:
# load_boston(), load_iris(), load_diabetes(), load_linnerud()
# available_sns_data() to look at seaborn data available
# sns_data(data="tips") -> to get sns data
# scikitlearn_data(data="load_boston") -> load_iris for iris data etc.

# %%
df = c_0_0_create_dataset.sns_data()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # shuffle the index of df

# %%
shuffled_index = list(df.index)

# %%
random.shuffle(shuffled_index)

# %%
df.index = shuffled_index

# %% [markdown]
# # check top and bottom few rows

# %%
df.head(2)
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 204       16.99  1.01  Female     No  Sun  Dinner     2
# 112       10.34  1.66    Male     No  Sun  Dinner     3

# %%
df[0:2]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 204       16.99  1.01  Female     No  Sun  Dinner     2
# 112       10.34  1.66    Male     No  Sun  Dinner     3

# %%
df.tail(2)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 106       17.82  1.75    Male     No   Sat  Dinner     2
# 226       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# # Slicing based on loc

# %%
df.loc[228:160]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 228       30.40  5.60    Male     No  Sun  Dinner     4
# 89        18.29  3.00    Male     No  Sun  Dinner     2
# 56        22.23  5.00    Male     No  Sun  Dinner     2
# 158       32.40  6.00    Male     No  Sun  Dinner     4
# 33        28.55  2.05    Male     No  Sun  Dinner     3
# 118       18.04  3.00    Male     No  Sun  Dinner     2
# 71        12.54  2.50    Male     No  Sun  Dinner     2
# 208       10.29  2.60  Female     No  Sun  Dinner     2
# 66        34.81  5.20  Female     No  Sun  Dinner     4
# 122        9.94  1.56    Male     No  Sun  Dinner     2
# 87        25.56  4.34    Male     No  Sun  Dinner     4
# 171       19.49  3.51    Male     No  Sun  Dinner     2
# 141       38.01  3.00    Male    Yes  Sat  Dinner     4
# 240       26.41  1.50  Female     No  Sat  Dinner     2
# 69        11.24  1.76    Male    Yes  Sat  Dinner     2
# 189       48.27  6.73    Male     No  Sat  Dinner     4
# ...

# %%
df.loc[160:228]
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size]
# Index: []

# %%
df.loc[228:228]
# Out:
#      total_bill  tip   sex smoker  day    time  size
# 228        30.4  5.6  Male     No  Sun  Dinner     4

# %% [markdown]
# # Slicing based on iloc

# %%
df.iloc[0:5]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 204       16.99  1.01  Female     No  Sun  Dinner     2
# 112       10.34  1.66    Male     No  Sun  Dinner     3
# 121       21.01  3.50    Male     No  Sun  Dinner     3
# 120       23.68  3.31    Male     No  Sun  Dinner     2
# 23        24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # get dataframe based on two different index

# %%
pd.concat([df.loc[0:0], df.loc[10:10]])
# Out:
#     total_bill   tip   sex smoker  day    time  size
# 0        48.33  9.00  Male     No  Sat  Dinner     4
# 10       18.29  3.76  Male    Yes  Sat  Dinner     4

# %% [markdown]
# # first 5 and last 5

# %%
df[:5]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 204       16.99  1.01  Female     No  Sun  Dinner     2
# 112       10.34  1.66    Male     No  Sun  Dinner     3
# 121       21.01  3.50    Male     No  Sun  Dinner     3
# 120       23.68  3.31    Male     No  Sun  Dinner     2
# 23        24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.head(5)
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 204       16.99  1.01  Female     No  Sun  Dinner     2
# 112       10.34  1.66    Male     No  Sun  Dinner     3
# 121       21.01  3.50    Male     No  Sun  Dinner     3
# 120       23.68  3.31    Male     No  Sun  Dinner     2
# 23        24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.iloc[:5]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 204       16.99  1.01  Female     No  Sun  Dinner     2
# 112       10.34  1.66    Male     No  Sun  Dinner     3
# 121       21.01  3.50    Male     No  Sun  Dinner     3
# 120       23.68  3.31    Male     No  Sun  Dinner     2
# 23        24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.iloc[-5:]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 4         29.03  5.92    Male     No   Sat  Dinner     3
# 217       27.18  2.00  Female    Yes   Sat  Dinner     2
# 239       22.67  2.00    Male    Yes   Sat  Dinner     2
# 106       17.82  1.75    Male     No   Sat  Dinner     2
# 226       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df[-5:]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 4         29.03  5.92    Male     No   Sat  Dinner     3
# 217       27.18  2.00  Female    Yes   Sat  Dinner     2
# 239       22.67  2.00    Male    Yes   Sat  Dinner     2
# 106       17.82  1.75    Male     No   Sat  Dinner     2
# 226       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.tail(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 4         29.03  5.92    Male     No   Sat  Dinner     3
# 217       27.18  2.00  Female    Yes   Sat  Dinner     2
# 239       22.67  2.00    Male    Yes   Sat  Dinner     2
# 106       17.82  1.75    Male     No   Sat  Dinner     2
# 226       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# # With loc it is completely different

# %%
df.loc[:5]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 204       16.99  1.01  Female     No  Sun  Dinner     2
# 112       10.34  1.66    Male     No  Sun  Dinner     3
# 121       21.01  3.50    Male     No  Sun  Dinner     3
# 120       23.68  3.31    Male     No  Sun  Dinner     2
# 23        24.59  3.61  Female     No  Sun  Dinner     4
# 3         25.29  4.71    Male     No  Sun  Dinner     4
# 72         8.77  2.00    Male     No  Sun  Dinner     2
# 68        26.88  3.12    Male     No  Sun  Dinner     4
# 61        15.04  1.96    Male     No  Sun  Dinner     2
# 79        14.78  3.23    Male     No  Sun  Dinner     2
# 127       10.27  1.71    Male     No  Sun  Dinner     2
# 225       35.26  5.00  Female     No  Sun  Dinner     4
# 197       15.42  1.57    Male     No  Sun  Dinner     2
# 173       18.43  3.00    Male     No  Sun  Dinner     4
# 196       14.83  3.02  Female     No  Sun  Dinner     2
# 237       21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %% [markdown]
# # Now these will return a series

# %%
df.loc[228]
# Out:
# total_bill      30.4
# tip              5.6
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               4
# Name: 228, dtype: object

# %%
df.iloc[5]
# Out:
# total_bill     25.29
# tip             4.71
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               4
# Name: 3, dtype: object

# %% [markdown]
# # You may convert those to dataframe

# %%
pd.DataFrame(df.loc[228]).T  # But probably not so efficient
# Out:
#     total_bill  tip   sex smoker  day    time size
# 228       30.4  5.6  Male     No  Sun  Dinner    4

# %% [markdown]
# # Returns a DataFrame of the third and second to last rows:

# %%
df.iloc[[2, -2]]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 121       21.01  3.50  Male     No  Sun  Dinner     3
# 106       17.82  1.75  Male     No  Sat  Dinner     2

# %%
df.iloc[:5:3]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 204       16.99  1.01  Female     No  Sun  Dinner     2
# 120       23.68  3.31    Male     No  Sun  Dinner     2

# %%
df.head()
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 204       16.99  1.01  Female     No  Sun  Dinner     2
# 112       10.34  1.66    Male     No  Sun  Dinner     3
# 121       21.01  3.50    Male     No  Sun  Dinner     3
# 120       23.68  3.31    Male     No  Sun  Dinner     2
# 23        24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # iloc again

# %%
df.iloc[:,0:2].head()
# Out:
#      total_bill   tip
# 204       16.99  1.01
# 112       10.34  1.66
# 121       21.01  3.50
# 120       23.68  3.31
# 23        24.59  3.61

# %%
df.iloc[0]
# Out:
# total_bill     16.99
# tip             1.01
# sex           Female
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 204, dtype: object

# %%
df.iloc[-1]
# Out:
# total_bill     18.78
# tip                3
# sex           Female
# smoker            No
# day             Thur
# time          Dinner
# size               2
# Name: 226, dtype: object

# %%
df.iloc[:,-1]
# Out:
# 204    2
# 112    3
# 121    3
# 120    2
# 23     4
#       ..
# 4      3
# 217    2
# 239    2
# 106    2
# 226    2
# Name: size, Length: 244, dtype: int64

# %%
df.iloc[:,0:5]
# Out:
#      total_bill   tip     sex smoker   day
# 204       16.99  1.01  Female     No   Sun
# 112       10.34  1.66    Male     No   Sun
# 121       21.01  3.50    Male     No   Sun
# 120       23.68  3.31    Male     No   Sun
# 23        24.59  3.61  Female     No   Sun
# ..          ...   ...     ...    ...   ...
# 4         29.03  5.92    Male     No   Sat
# 217       27.18  2.00  Female    Yes   Sat
# 239       22.67  2.00    Male    Yes   Sat
# 106       17.82  1.75    Male     No   Sat
# 226       18.78  3.00  Female     No  Thur
#
# [244 rows x 5 columns]

# %%
df.iloc[[0,3,6]]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 204       16.99  1.01  Female     No  Sun  Dinner     2
# 120       23.68  3.31    Male     No  Sun  Dinner     2
# 72         8.77  2.00    Male     No  Sun  Dinner     2

# %%
df.iloc[0:5,1:5] # first five rows and 1-5 columns of dataframe
# Out:
#       tip     sex smoker  day
# 204  1.01  Female     No  Sun
# 112  1.66    Male     No  Sun
# 121  3.50    Male     No  Sun
# 120  3.31    Male     No  Sun
# 23   3.61  Female     No  Sun

# %% [markdown]
# # lets set another index

# %%
df.set_index(["tip"], inplace=True)

# %%
df.head()
# Out:
#       total_bill     sex smoker  day    time  size
# tip
# 1.01       16.99  Female     No  Sun  Dinner     2
# 1.66       10.34    Male     No  Sun  Dinner     3
# 3.50       21.01    Male     No  Sun  Dinner     3
# 3.31       23.68    Male     No  Sun  Dinner     2
# 3.61       24.59  Female     No  Sun  Dinner     4

# %%
df.index.name=None

# %%
df.head()
# Out:
#       total_bill     sex smoker  day    time  size
# 1.01       16.99  Female     No  Sun  Dinner     2
# 1.66       10.34    Male     No  Sun  Dinner     3
# 3.50       21.01    Male     No  Sun  Dinner     3
# 3.31       23.68    Male     No  Sun  Dinner     2
# 3.61       24.59  Female     No  Sun  Dinner     4

# %% [markdown]
# # Fill NA forward fill and backward fill

# %%
df['total_bill'].fillna(method='ffill', inplace=True)

# %%
df['sex'].fillna(method='bfill', inplace=True)

# %% [markdown]
# # reset_index to regular

# %%
df.head()
# Out:
#       total_bill     sex smoker  day    time  size
# 1.01       16.99  Female     No  Sun  Dinner     2
# 1.66       10.34    Male     No  Sun  Dinner     3
# 3.50       21.01    Male     No  Sun  Dinner     3
# 3.31       23.68    Male     No  Sun  Dinner     2
# 3.61       24.59  Female     No  Sun  Dinner     4

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    total_bill     sex smoker  day    time  size
# 0       16.99  Female     No  Sun  Dinner     2
# 1       10.34    Male     No  Sun  Dinner     3
# 2       21.01    Male     No  Sun  Dinner     3
# 3       23.68    Male     No  Sun  Dinner     2
# 4       24.59  Female     No  Sun  Dinner     4

# %% [markdown]
# # Check column values based on loc

# %%
df.head()
# Out:
#    total_bill     sex smoker  day    time  size
# 0       16.99  Female     No  Sun  Dinner     2
# 1       10.34    Male     No  Sun  Dinner     3
# 2       21.01    Male     No  Sun  Dinner     3
# 3       23.68    Male     No  Sun  Dinner     2
# 4       24.59  Female     No  Sun  Dinner     4

# %%
df.loc[1, "sex"]
# Out:
# 'Male'

# %%
df.loc[1,["sex"]]
# Out:
# sex    Male
# Name: 1, dtype: object

# %%
df.loc[0,["sex"]]
# Out:
# sex    Female
# Name: 0, dtype: object

# %%
# Repeat and check
df["total_bill"].values[df["sex"]=="Female"] = 0

# %%
df.head()
# Out:
#    total_bill     sex smoker  day    time  size
# 0        0.00  Female     No  Sun  Dinner     2
# 1       10.34    Male     No  Sun  Dinner     3
# 2       21.01    Male     No  Sun  Dinner     3
# 3       23.68    Male     No  Sun  Dinner     2
# 4        0.00  Female     No  Sun  Dinner     4

# %% [markdown]
# # Sum one column based on another column

# %%
df.head(2)
# Out:
#    total_bill     sex smoker  day    time  size
# 0        0.00  Female     No  Sun  Dinner     2
# 1       10.34    Male     No  Sun  Dinner     3

# %%
df[df['sex']=='Male']['total_bill'].sum()
# Out:
# 3256.8199999999997

# %%
df[df['sex']=='Female']['total_bill'].sum()
# Out:
# 0.0
